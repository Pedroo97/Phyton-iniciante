# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedroo97/Pedroo97/blob/main/Tratamento_de_erros_e_exce%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tratamento de erros e exceções
#
# - NameError: variável nao foi definida
# - TypeError: tipos de dados incompatíveis
# - RuntimeError: erro de execução
# - SyntaxError: sintaxe digitada é inválida e não reconhecida pelo interpretador
# - ZeroDivisionError: divisão por zero
# - IndexError: índice está fora da coleção

# %% [markdown]
# ## Tipos de erros

# %%
3 = 4
# Out:
#   File "<ipython-input-3-effb9ca1a7d0>", line 1
#     3 = 4
#          ^
# SyntaxError: can't assign to literal

# %%
print('Meu nome é', nome)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8814f7563975> in <module>()
# ----> 1 print('Meu nome é', nome)
#
# NameError: name 'nome' is not defined

# %%
print(3 / 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-76ea80225931> in <module>()
# ----> 1 print(3 / 0)
#
# ZeroDivisionError: division by zero

# %%
2.3 / 'cachorro'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-48ef6fd474fe> in <module>()
# ----> 1 2.3 / 'cachorro'
#
# TypeError: unsupported operand type(s) for /: 'float' and 'str'

# %%
c = [1,2,3,4,5]
c
# Out:
# [1, 2, 3, 4, 5]

# %%
c[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-513c54dffebd> in <module>()
# ----> 1 c[5]
#
# IndexError: list index out of range

# %% [markdown]
# ## Tratamento de erros

# %%
try:   #tenta executar todo código abaixo
  n = int(input('Digite um número inteiro: '))  #INT usado para buscar um numero inteiro para calculos 
except:   #usado para tratamento de exceções
  print('Valor inválido')
else: #caso o valor seja correto
  print(f'Valor digitado é {n}')
# Out:
# Digite um número inteiro: 8
# Valor digitado é 8

# %%
while True: #loop infinito
  try:
    n = int(input('Digite um número inteiro: '))
  except:
    print('Valor inválido')
  else:
    print(f'Valor digitado é {n}')
    break #usado para sair do while ou seja loop infinito
# Out:
# Digite um número inteiro: 78
# Valor digitado é 78

# %%
while True:
  try:
    p = int(input('Digite um número inteiro'))
  except ValueError:
    print('Valor inválido')
  except KeyboardInterrupt:  #usuario pode forçar a interrupção
    print('Usuário interrompeu a execução')
    break
  else:
    print(f'Valor digitado é {p}')
    break
# Out:
# Digite um número inteirop
# Valor inválido
# Digite um número inteirom
# Valor inválido
# Digite um número inteiro8
# Valor digitado é 8
